# %%
# !pip install yfinance
# Out:
# ...
# Using legacy 'setup.py install' for yfinance, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for multitasking, since package 'wheel' is not installed.
# ...
#     Running setup.py install for multitasking: started
#     Running setup.py install for multitasking: finished with status 'done'
#     Running setup.py install for yfinance: started
#     Running setup.py install for yfinance: finished with status 'done'
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %matplotlib inline

# %%
aapl = yf.Ticker('AAPL')

# %%
days = 50
history = aapl.history(period=f'{days}d')
history.head(3)
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2021-07-30  144.164003  146.111083  143.894403  145.641785  70382000
# 2021-08-02  146.141047  146.730161  145.032707  145.302307  62880000
# 2021-08-03  145.591857  147.818517  144.962795  147.139542  64786600
#
#             Dividends  Stock Splits
# Date
# 2021-07-30        0.0             0
# 2021-08-02        0.0             0
# 2021-08-03        0.0             0

# %%
history.index
# Out:
# DatetimeIndex(['2021-07-30', '2021-08-02', '2021-08-03', '2021-08-04',
#                '2021-08-05', '2021-08-06', '2021-08-09', '2021-08-10',
#                '2021-08-11', '2021-08-12', '2021-08-13', '2021-08-16',
#                '2021-08-17', '2021-08-18', '2021-08-19', '2021-08-20',
#                '2021-08-23', '2021-08-24', '2021-08-25', '2021-08-26',
#                '2021-08-27', '2021-08-30', '2021-08-31', '2021-09-01',
#                '2021-09-02', '2021-09-03', '2021-09-07', '2021-09-08',
#                '2021-09-09', '2021-09-10', '2021-09-13', '2021-09-14',
#                '2021-09-15', '2021-09-16', '2021-09-17', '2021-09-20',
#                '2021-09-21', '2021-09-22', '2021-09-23', '2021-09-24',
#                '2021-09-27', '2021-09-28', '2021-09-29', '2021-09-30',
#                '2021-10-01', '2021-10-04', '2021-10-05', '2021-10-06',
#                '2021-10-07', '2021-10-08'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
history.index = history.index.strftime('%d %B %Y')
history.head()
# Out:
#                       Open        High         Low       Close    Volume  \
# Date
# 30 July 2021    144.164003  146.111083  143.894403  145.641785  70382000
# 02 August 2021  146.141047  146.730161  145.032707  145.302307  62880000
# 03 August 2021  145.591857  147.818517  144.962795  147.139542  64786600
# 04 August 2021  147.049692  147.568903  146.061168  146.730164  56368300
# 05 August 2021  146.760114  147.618828  145.951328  146.839996  46397700
#
#                 Dividends  Stock Splits
# Date
# 30 July 2021          0.0             0
# 02 August 2021        0.0             0
# 03 August 2021        0.0             0
# 04 August 2021        0.0             0
# 05 August 2021        0.0             0

# %%
history = history[['Close']]
history.columns = ['apple']
history.head()
# Out:
#                      apple
# Date
# 30 July 2021    145.641785
# 02 August 2021  145.302307
# 03 August 2021  147.139542
# 04 August 2021  146.730164
# 05 August 2021  146.839996

# %%
history = history.T
history
# Out:
# Date   30 July 2021  02 August 2021  03 August 2021  04 August 2021  \
# apple    145.641785      145.302307      147.139542      146.730164
#
# Date   05 August 2021  06 August 2021  09 August 2021  10 August 2021  \
# apple      146.839996      146.139999      146.089996      145.600006
#
# Date   11 August 2021  12 August 2021  ...  27 September 2021  \
# apple      145.860001      148.889999  ...         145.369995
#
# Date   28 September 2021  29 September 2021  30 September 2021  \
# apple         141.910004         142.830002              141.5
#
# Date   01 October 2021  04 October 2021  05 October 2021  06 October 2021  \
# apple       142.649994       139.139999       141.110001            142.0
#
# Date   07 October 2021  08 October 2021
# apple       143.289993       142.899994
#
# [1 rows x 50 columns]

# %%
history.index.name = 'Name'

# %%
history
# Out:
# Date   30 July 2021  02 August 2021  03 August 2021  04 August 2021  \
# Name
# apple    145.641785      145.302307      147.139542      146.730164
#
# Date   05 August 2021  06 August 2021  09 August 2021  10 August 2021  \
# Name
# apple      146.839996      146.139999      146.089996      145.600006
#
# Date   11 August 2021  12 August 2021  ...  27 September 2021  \
# Name                                   ...
# apple      145.860001      148.889999  ...         145.369995
#
# Date   28 September 2021  29 September 2021  30 September 2021  \
# Name
# apple         141.910004         142.830002              141.5
#
# Date   01 October 2021  04 October 2021  05 October 2021  06 October 2021  \
# Name
# apple       142.649994       139.139999       141.110001            142.0
#
# Date   07 October 2021  08 October 2021
# Name
# apple       143.289993       142.899994
#
# [1 rows x 50 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

days = 50
tickers = {
    'apple': 'AAPL',
    'facebook': 'FB',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN'
}

def get_data(days, tickers):
    df = pd.DataFrame()
    for company in tickers.keys():
        tkr = yf.Ticker(tickers[company])
        history = tkr.history(period=f'{days}d')
        history.index = history.index.strftime('%d %B %Y')
        history = history[['Close']]
        history.columns = [company]
        history = history.T
        history.index.name = 'Name'
        df = pd.concat([df,history])
    return df
df = get_data(days, tickers)

# %%
import altair as alt
df
# Out:
# Date       30 July 2021  02 August 2021  03 August 2021  04 August 2021  \
# Name
# apple        145.641785      145.302307      147.139542      146.730164
# facebook     356.299988      351.950012      351.239990      358.920013
# google      2694.530029     2697.090088     2712.600098     2702.510010
# microsoft    284.365601      284.275787      286.571381      285.962555
# netflix      517.570007      515.150024      510.820007      517.349976
# amazon      3327.590088     3331.479980     3366.239990     3354.719971
#
# Date       05 August 2021  06 August 2021  09 August 2021  10 August 2021  \
# Name
# apple          146.839996      146.139999      146.089996      145.600006
# facebook       362.970001      363.510010      361.609985      361.130005
# google        2725.030029     2714.770020     2738.260010     2736.139893
# microsoft      288.966797      288.906921      287.779053      285.892700
# netflix        524.890015      520.549988      519.969971      515.840027
# ...

# %%
companies = ['apple', 'facebook']
data = df.loc[companies]
data
# Out:
# Date      30 July 2021  02 August 2021  03 August 2021  04 August 2021  \
# Name
# apple       145.641785      145.302307      147.139542      146.730164
# facebook    356.299988      351.950012      351.239990      358.920013
#
# Date      05 August 2021  06 August 2021  09 August 2021  10 August 2021  \
# Name
# apple         146.839996      146.139999      146.089996      145.600006
# facebook      362.970001      363.510010      361.609985      361.130005
#
# Date      11 August 2021  12 August 2021  ...  27 September 2021  \
# Name                                      ...
# apple         145.860001      148.889999  ...         145.369995
# facebook      359.959991      362.649994  ...         353.579987
#
# Date      28 September 2021  29 September 2021  30 September 2021  \
# Name
# apple            141.910004         142.830002         141.500000
# facebook         340.649994         339.609985         339.390015
#
# ...

# %%
data.sort_index()
# Out:
# Date      30 July 2021  02 August 2021  03 August 2021  04 August 2021  \
# Name
# apple       145.641785      145.302307      147.139542      146.730164
# facebook    356.299988      351.950012      351.239990      358.920013
#
# Date      05 August 2021  06 August 2021  09 August 2021  10 August 2021  \
# Name
# apple         146.839996      146.139999      146.089996      145.600006
# facebook      362.970001      363.510010      361.609985      361.130005
#
# Date      11 August 2021  12 August 2021  ...  27 September 2021  \
# Name                                      ...
# apple         145.860001      148.889999  ...         145.369995
# facebook      359.959991      362.649994  ...         353.579987
#
# Date      28 September 2021  29 September 2021  30 September 2021  \
# Name
# apple            141.910004         142.830002         141.500000
# facebook         340.649994         339.609985         339.390015
#
# ...

# %%
data = data.T.reset_index()
data.head()
# Out:
# Name            Date       apple    facebook
# 0       30 July 2021  145.641785  356.299988
# 1     02 August 2021  145.302307  351.950012
# 2     03 August 2021  147.139542  351.239990
# 3     04 August 2021  146.730164  358.920013
# 4     05 August 2021  146.839996  362.970001

# %%
data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'Stock Prices(USD)'}
)
data
# Out:
#                Date      Name  Stock Prices(USD)
# 0      30 July 2021     apple         145.641785
# 1    02 August 2021     apple         145.302307
# 2    03 August 2021     apple         147.139542
# 3    04 August 2021     apple         146.730164
# 4    05 August 2021     apple         146.839996
# ..              ...       ...                ...
# 95  04 October 2021  facebook         326.230011
# 96  05 October 2021  facebook         332.959991
# 97  06 October 2021  facebook         333.640015
# 98  07 October 2021  facebook         329.220001
# 99  08 October 2021  facebook         330.049988
#
# [100 rows x 3 columns]

# %%
chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Stock Prices(USD):Q", stack=None),
        color='Name:N'
    )
)
chart
# Out:
# alt.Chart(...)
